# %% [markdown]
# multiple lines, single plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# random low and high temperature data

# %%
data_set_size = 15
low_mu, low_sigma = 50, 4.3
low_data_set = low_mu + low_sigma * np.random.randn(data_set_size)
high_mu,  high_sigma = 57, 5.2
high_data_set = high_mu + high_sigma * np.random.randn(data_set_size)

days = list(range(1, data_set_size + 1))
print(low_data_set, "\n", high_data_set)
# Out:
# [52.07550208 51.21247125 50.66837481 43.72974777 55.08568705 49.3217511
#  48.23799674 53.85879135 43.7899585  59.74163287 47.72598611 44.35959969
#  41.40950429 53.98620783 54.4210178 ]
#  [48.79574314 55.73084421 63.63865204 58.66269391 60.52432573 58.28030154
#  51.84839157 51.98123546 52.97710906 56.79355956 57.29229448 57.98359639
#  58.32271553 56.35943532 56.03981001]

# %%
plt.plot(days, low_data_set)
plt.show()

# %%
plt.plot(days, low_data_set,
		days, low_data_set, 'vm',
		days, high_data_set,
		days, high_data_set, '^k')
plt.show()

# %%
plt.plot(days, low_data_set,
		days, high_data_set)
plt.xlabel('day')
plt.ylabel('temperature: degrees fahrenheit')
plt.title('randomized temperature data')
plt.show()

# %%
t1 = np.arange(0.0, 2.0, 0.1)
t2 = np.arange(0.0, 2.0, 0.01)

l1, = plt.plot(t2, np.exp(-t2))
l2, l3 = plt.plot(t2, np.sin(2 * np.pi * t2), '--go', t1, np.log(1 + t1), '.')
l4, = plt.plot(t2, np.exp(-t2) * np.sin(2 * np.pi * t2), 'rs-.')

plt.legend((12, 14), ('oscilatory', 'damped'), loc='upper right', shadow=True)
plt.xlabel('time')
plt.ylabel('volts')
plt.title('damped oscilation')
plt.show()
# Out:
# /tmp/ipykernel_74064/3390545242.py:8: UserWarning: Legend does not support 12 instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend((12, 14), ('oscilatory', 'damped'), loc='upper right', shadow=True)
# /tmp/ipykernel_74064/3390545242.py:8: UserWarning: Legend does not support 14 instances.
# A proxy artist may be used instead.
# See: https://matplotlib.org/users/legend_guide.html#creating-artists-specifically-for-adding-to-the-legend-aka-proxy-artists
#   plt.legend((12, 14), ('oscilatory', 'damped'), loc='upper right', shadow=True)
